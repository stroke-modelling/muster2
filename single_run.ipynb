# %% [markdown]
# # MSU Deterministic Model

# %%
import numpy as np
import pandas as pd

from classes.geography_processing import Geoprocessing
from classes.model import Model
from classes.scenario import Scenario

# %%
# Set up scenario
scenario = Scenario({
    'name': 1,
    'limit_to_england' : True
})

# Process and save geographic data (only needed when hospital data changes)
geo = Geoprocessing(); geo.run()

# Set up model
model = Model(
    scenario=scenario,
    geodata=pd.read_csv('processed_data/processed_data.csv'))

# Run model
model.run()

# %%
model.full_results.head().T
# Out:
# LSOA                         Adur 001A Adur 001B Adur 001C Adur 001D Adur 001E
# nearest_ivt_unit                BN25BE    BN25BE   BN112DH   BN112DH   BN112DH
# nearest_ivt_time                  17.6      18.7      17.6      17.6      16.5
# nearest_mt_unit                 BN25BE    BN25BE    BN25BE    BN25BE    BN25BE
# nearest_mt_time                   17.6      18.7      19.8      19.8      19.8
# transfer_unit                   BN25BE    BN25BE    BN25BE    BN25BE    BN25BE
# ...                                ...       ...       ...       ...       ...
# lvo_msu_mt_utility_shift      0.165051  0.163731  0.162412  0.162412  0.162412
# lvo_msu_ivt_mt_mrs_0-2        0.439626  0.438199  0.436772  0.436772  0.436772
# lvo_msu_ivt_mt_mrs_shift     -0.836467 -0.829295 -0.822131 -0.822131 -0.822131
# lvo_msu_ivt_mt_utility        0.497661  0.496341  0.495022  0.495022  0.495022
# lvo_msu_ivt_mt_utility_shift  0.165051  0.163731  0.162412  0.162412  0.162412
#
# [71 rows x 5 columns]

# %%
model.full_results.describe().T
# Out:
#                                 count       mean        std       min  \
# nearest_ivt_time              32843.0  19.506062   8.296385  5.800000
# nearest_mt_time               32843.0  34.009956  19.658634  5.800000
# transfer_time                 32843.0  26.528521  23.426822  0.000000
# nearest_msu_time              32843.0  34.526197  19.828598  5.800000
# Admissions                    32843.0   2.466063   1.418715  0.100000
# ...                               ...        ...        ...       ...
# lvo_msu_mt_utility_shift      31019.0   0.145375   0.023597  0.029746
# lvo_msu_ivt_mt_mrs_0-2        31019.0   0.418503   0.025210  0.297391
# lvo_msu_ivt_mt_mrs_shift      31019.0  -0.730996   0.125681 -0.913954
# lvo_msu_ivt_mt_utility        31019.0   0.477985   0.023597  0.362356
# lvo_msu_ivt_mt_utility_shift  31019.0   0.145375   0.023597  0.029746
#
#                                     25%        50%        75%         max
# nearest_ivt_time              13.300000  17.600000  24.100000   74.500000
# nearest_mt_time               19.800000  29.400000  43.400000  134.700000
# transfer_time                  0.000000  27.300000  40.200000  117.500000
# nearest_msu_time              19.800000  29.400000  44.500000  134.700000
# Admissions                     1.333333   2.333333   3.333333   19.333333
# ...                                 ...        ...        ...         ...
# lvo_msu_mt_utility_shift       0.134258   0.150922   0.162412    0.179239
# lvo_msu_ivt_mt_mrs_0-2         0.406456   0.424370   0.436772    0.454998
# lvo_msu_ivt_mt_mrs_shift      -0.822131  -0.759995  -0.670637   -0.126304
# lvo_msu_ivt_mt_utility         0.466868   0.483532   0.495022    0.511849
# lvo_msu_ivt_mt_utility_shift   0.134258   0.150922   0.162412    0.179239
#
# [66 rows x 8 columns]
