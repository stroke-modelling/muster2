# %%
import numpy as np
import pandas as pd

from classes.model import Model
from classes.scenario import Scenario

# %%
# Scenario overwrites default values
scenario = Scenario({
    "run_duration": 100 * 365,  # days
    "mt_hub_postcodes":['B152TH'],
    "use_msu": False,
    "probability_mt": 0
})

model = Model(scenario)

model.run()

model.results_all.to_csv('./temp/standard_ivt_only.csv')

model.results_summary_all
# Out:
#            time_ambulance_called  time_ambulance_arrival  \
# statistic
# mean                        60.0                    80.0
# std                          0.0                     0.0
#
#            time_ambulance_leaves_scene  time_admitting_unit_arrival  \
# statistic
# mean                             110.0                   129.180858
# std                                0.0                     7.711060
#
#            time_needle  time_transfer_unit_arrival  time_puncture  mRS shift  \
# statistic
# mean        169.176290                         NaN            NaN  -0.399362
# std           7.710939                         NaN            NaN   0.138940
#
#            utility_shift   mRS 0-2
# statistic
# mean            0.075046  0.558176
# std             0.023330  0.172368

# %%
from classes.model import Model
from classes.scenario import Scenario


# Scenario overwrites default values
scenario = Scenario({
    "run_duration": 100 * 365,  # days
    "mt_hub_postcodes":['B152TH'],
    "use_msu": False,
    "probability_mt": 0,
    "probability_ivt": 0
})

model = Model(scenario)

model.run()

model.results_all.to_csv('./temp/no_treatment.csv')

model.results_summary_all
# Out:
#            time_ambulance_called  time_ambulance_arrival  \
# statistic
# mean                        60.0                    80.0
# std                          0.0                     0.0
#
#            time_ambulance_leaves_scene  time_admitting_unit_arrival  \
# statistic
# mean                             110.0                   129.157173
# std                                0.0                     7.704917
#
#            time_needle  time_transfer_unit_arrival  time_puncture  mRS shift  \
# statistic
# mean               NaN                         NaN            NaN        0.0
# std                NaN                         NaN            NaN        0.0
#
#            utility_shift   mRS 0-2
# statistic
# mean                 0.0  0.477031
# std                  0.0  0.147759

# %%
# Scenario overwrites default values
scenario = Scenario({
    "run_duration": 100 * 365,  # days
    "mt_hub_postcodes":['B152TH'],
    "use_msu": False,
    "probability_mt": 1
})

model = Model(scenario)

model.run()

model.results_all.to_csv('./temp/standard_ivt_mt.csv')

model.results_summary_all
# Out:
#            time_ambulance_called  time_ambulance_arrival  \
# statistic
# mean                        60.0                    80.0
# std                          0.0                     0.0
#
#            time_ambulance_leaves_scene  time_admitting_unit_arrival  \
# statistic
# mean                             110.0                   129.170155
# std                                0.0                     7.699660
#
#            time_needle  time_transfer_unit_arrival  time_puncture  mRS shift  \
# statistic
# mean        169.168327                  262.038488     281.579775  -0.488240
# std           7.705418                   18.767591      56.150140   0.101241
#
#            utility_shift   mRS 0-2
# statistic
# mean            0.092944  0.576839
# std             0.019157  0.147477

# %%
# Scenario overwrites default values
scenario = Scenario({
    "run_duration": 100 * 365,  # days
    "mt_hub_postcodes":['B152TH'],
    "use_msu": True,
    "probability_mt": 0
})

model = Model(scenario)

model.run()

model.results_all.to_csv('./temp/msu_ivt_only.csv')

model.results_summary_all
# Out:
#            time_ambulance_called  time_ambulance_arrival  \
# statistic
# mean                        60.0                     NaN
# std                          0.0                     NaN
#
#            time_ambulance_leaves_scene  time_admitting_unit_arrival  \
# statistic
# mean                               NaN                   154.299114
# std                                NaN                    19.708120
#
#            time_needle  time_transfer_unit_arrival  time_puncture  \
# statistic
# mean        122.236814                         NaN            NaN
# std          14.874434                         NaN            NaN
#
#            time_msu_arrival  mRS shift  utility_shift   mRS 0-2
# statistic
# mean             102.231573  -0.498805       0.092556  0.577661
# std               14.886306   0.161287       0.026913  0.176017

# %%
# Scenario overwrites default values
scenario = Scenario({
    "run_duration": 100 * 365,  # days
    "mt_hub_postcodes":['B152TH'],
    "use_msu": True,
    "probability_mt": 1
})

model = Model(scenario)

model.run()

model.results_all.to_csv('./temp/msu_ivt_mt.csv')

model.results_summary_all
# Out:
#            time_ambulance_called  time_ambulance_arrival  \
# statistic
# mean                        60.0                     NaN
# std                          0.0                     NaN
#
#            time_ambulance_leaves_scene  time_admitting_unit_arrival  \
# statistic
# mean                               NaN                   156.779215
# std                                NaN                    22.774709
#
#            time_needle  time_transfer_unit_arrival  time_puncture  \
# statistic
# mean        122.232732                         NaN     169.558481
# std          14.849656                         NaN      29.712392
#
#            time_msu_arrival  mRS shift  utility_shift   mRS 0-2
# statistic
# mean             102.246246  -0.678581       0.127689  0.614175
# std               14.877315   0.118036       0.026717  0.123886

# %%
msoa = pd.read_csv('./data/lsoa_to_msoa.csv')

# %%
model.results_summary_all
# Out:
#            time_ambulance_called  time_ambulance_arrival  \
# statistic
# mean                        60.0                     NaN
# std                          0.0                     NaN
#
#            time_ambulance_leaves_scene  time_admitting_unit_arrival  \
# statistic
# mean                               NaN                   156.779215
# std                                NaN                    22.774709
#
#            time_needle  time_transfer_unit_arrival  time_puncture  \
# statistic
# mean        122.232732                         NaN     169.558481
# std          14.849656                         NaN      29.712392
#
#            time_msu_arrival  mRS shift  utility_shift   mRS 0-2
# statistic
# mean             102.246246  -0.678581       0.127689  0.614175
# std               14.877315   0.118036       0.026717  0.123886

# %%
model.results_summary_by_admitting_unit
# Out:
#                  time_ambulance_called      time_ambulance_arrival      \
#                                   mean  std                   mean std
# closest_ivt_unit
# B152TH                            60.0  0.0                    NaN NaN
# B714HJ                            60.0  0.0                    NaN NaN
# DY12HQ                            60.0  0.0                    NaN NaN
# HR12ER                            60.0  0.0                    NaN NaN
# TF16TF                            60.0  0.0                    NaN NaN
# WR51DD                            60.0  0.0                    NaN NaN
# WV100QP                           60.0  0.0                    NaN NaN
#
#                  time_ambulance_leaves_scene     time_admitting_unit_arrival  \
#                                         mean std                        mean
# closest_ivt_unit
# B152TH                                   NaN NaN                  141.297039
# ...

# %%
model.results_all[np.isnan(model.results_all['time_puncture']) == False]
# Out:
#             id                     lsoa  stroke_type closest_ivt_unit  \
# 5            6            Sandwell 006B            2           B714HJ
# 17          18          Birmingham 079A            2           B152TH
# 24          23       Herefordshire 020D            2           HR12ER
# 28          27       Herefordshire 013A            2           HR12ER
# 29          29  Telford and Wrekin 020B            2           TF16TF
# ...        ...                      ...          ...              ...
# 631290  631291          Birmingham 030C            2           B714HJ
# 631291  631292            Wychavon 004D            2           WR51DD
# 631292  631293          Shropshire 025D            2           TF16TF
# 631303  631303       Malvern Hills 001B            2           WR51DD
# 631304  631305          Shropshire 008A            2           TF16TF
#
#         closest_ivt_travel_duration closest_mt_unit  \
# 5                              13.3          B152TH
# ...

# %%
model.results_all[np.isnan(model.results_all['time_needle']) == False]
# Out:
#             id                    lsoa  stroke_type closest_ivt_unit  \
# 5            6           Sandwell 006B            2           B714HJ
# 11          12            Walsall 021D            1          WV100QP
# 17          18         Birmingham 079A            2           B152TH
# 18          19  Stratford-on-Avon 003D            1           B152TH
# 19          20             Dudley 003C            1           DY12HQ
# ...        ...                     ...          ...              ...
# 631300  631301             Dudley 036B            1           DY12HQ
# 631302  631304         Birmingham 045E            1           B714HJ
# 631303  631303      Malvern Hills 001B            2           WR51DD
# 631304  631305         Shropshire 008A            2           TF16TF
# 631306  631307      Herefordshire 019E            1           HR12ER
#
#         closest_ivt_travel_duration closest_mt_unit  \
# 5                              13.3          B152TH
# ...
