# %% [markdown]
# # MSU Deterministic Model

# %%
import numpy as np
import pandas as pd

from classes.geography_processing import Geoprocessing
from classes.model import Model
from classes.scenario import Scenario

# Imports from the stroke_outcome package:
from stroke_outcome.continuous_outcome import Continuous_outcome
import stroke_outcome.outcome_utilities as outcome_utilities

# %%
# Set up scenario
scenario = Scenario({
    'name': "Test",
    'limit_to_england' : False
})

# Process and save geographic data (only needed when hospital data changes)
geo = Geoprocessing(); geo.run()

# Set up model
model = Model(
    scenario=scenario,
    geodata=pd.read_csv('processed_data/processed_data.csv'))

# Run model
model.run()

# %%
model.full_results.head().T
# Out:
#                                             0          1          2  \
# LSOA                                Adur 001A  Adur 001B  Adur 001C
# nearest_ivt_unit                       BN25BE     BN25BE    BN112DH
# nearest_ivt_time                         17.6       18.7       17.6
# nearest_mt_unit                        BN25BE     BN25BE     BN25BE
# nearest_mt_time                          17.6       18.7       19.8
# transfer_unit                          BN25BE     BN25BE     BN25BE
# transfer_required                       False      False       True
# transfer_time                             0.0        0.0       31.6
# nearest_msu_unit                       BN25BE     BN25BE     BN25BE
# nearest_msu_time                         17.6       18.7       19.8
# Admissions                           1.333333   1.666667        2.0
# England                                     1          1          1
# drip_ship_ivt_time                      172.6      173.7      172.6
# drip_ship_mt_time                       232.6      233.7      264.2
# nlvo_no_treatment_mrs0-2                  NaN        NaN        NaN
# nlvo_no_treatment_utility             0.59964    0.59964    0.59964
# nlvo_drip_ship_ivt_mrs0-2            0.676764   0.676247   0.676764
# nlvo_drip_ship_ivt_mrs_shift        -0.487237  -0.484546  -0.487237
# nlvo_drip_ship_ivt_utility           0.689369   0.688896   0.689369
# nlvo_drip_ship_ivt_utililityshift    0.089729   0.089256   0.089729
# lvo_drip_ship_ivt_mrs0-2             0.310061   0.309749   0.310061
# lvo_drip_ship_ivt_mrs_shift         -0.196524  -0.194922  -0.196524
# lvo_drip_ship_ivt_utility            0.373541   0.373245   0.373541
# lvo_drip_ship_ivt_utility_shift      0.040931   0.040635   0.040931
# lvo_drip_ship_mt_mrs0-2              0.396453    0.39576   0.376712
# lvo_drip_ship_mt_mrs_shift          -0.196524  -0.194922  -0.196524
# lvo_drip_ship_mt_utility              0.45752   0.456871   0.438965
# lvo_drip_ship_mt_utility_shift       0.040931   0.040635   0.040931
# mothership_ivt_time                     172.6      173.7      174.8
# mothership_mt_time                      172.6      173.7      174.8
# nlvo_mothership_ivt_mrs0-2           0.676764   0.676247    0.67573
# nlvo_mothership_ivt_mrs_shift       -0.487237  -0.484546  -0.481854
# nlvo_mothership_ivt_utility          0.689369   0.688896   0.688423
# nlvo_mothership_ivt_utililityshift   0.089729   0.089256   0.088783
# lvo_mothership_ivt_mrs0-2            0.310061   0.309749   0.309438
# lvo_mothership_ivt_mrs_shift        -0.196524  -0.194922   -0.19332
# lvo_mothership_ivt_utility           0.373541   0.373245   0.372949
# lvo_mothership_ivt_utility_shift     0.040931   0.040635   0.040339
# lvo_mothership_mt_mrs0-2             0.434829   0.434117   0.433405
# lvo_mothership_mt_mrs_shift         -0.196524  -0.194922   -0.19332
# lvo_mothership_mt_utility            0.493224   0.492565   0.491906
# lvo_mothership_mt_utility_shift      0.040931   0.040635   0.040339
# msu_ivt_time                            107.6      108.7      109.8
# msu_mt_time                             180.2      182.4      184.6
# msu_occupied_treatment                   75.2       77.4       79.6
# msu_occupied_no_treatment                57.6       58.7       59.8
# nlvo_msu_ivt_mrs0-2                  0.706494   0.706005   0.705514
# nlvo_msu_ivt_mrs_shift              -0.643469  -0.640871  -0.638272
# nlvo_msu_ivt_utility                 0.716494   0.716049   0.715603
# nlvo_msu_ivt_utililityshift          0.116854   0.116409   0.115963
# lvo_msu_ivt_mrs0-2                   0.328789   0.328468   0.328146
# lvo_msu_ivt_mrs_shift               -0.293451  -0.291774  -0.290098
# lvo_msu_ivt_utility                  0.391328   0.391022   0.390717
# lvo_msu_ivt_utility_shift            0.058718   0.058412   0.058107
# lvo_msu_mt_mrs0-2                    0.429914   0.428494   0.427075
# lvo_msu_mt_mrs_shift                -0.293451  -0.291774  -0.290098
# lvo_msu_mt_utility                   0.488673   0.487357   0.486042
# lvo_msu_mt_utility_shift             0.058718   0.058412   0.058107
#
#                                             3          4
# LSOA                                Adur 001D  Adur 001E
# nearest_ivt_unit                      BN112DH    BN112DH
# nearest_ivt_time                         17.6       16.5
# nearest_mt_unit                        BN25BE     BN25BE
# nearest_mt_time                          19.8       19.8
# transfer_unit                          BN25BE     BN25BE
# transfer_required                        True       True
# transfer_time                            31.6       31.6
# nearest_msu_unit                       BN25BE     BN25BE
# nearest_msu_time                         19.8       19.8
# Admissions                                2.0   3.666667
# England                                     1          1
# drip_ship_ivt_time                      172.6      171.5
# drip_ship_mt_time                       264.2      263.1
# nlvo_no_treatment_mrs0-2                  NaN        NaN
# nlvo_no_treatment_utility             0.59964    0.59964
# nlvo_drip_ship_ivt_mrs0-2            0.676764    0.67728
# nlvo_drip_ship_ivt_mrs_shift        -0.487237  -0.489926
# nlvo_drip_ship_ivt_utility           0.689369   0.689842
# nlvo_drip_ship_ivt_utililityshift    0.089729   0.090202
# lvo_drip_ship_ivt_mrs0-2             0.310061   0.310373
# lvo_drip_ship_ivt_mrs_shift         -0.196524  -0.198128
# lvo_drip_ship_ivt_utility            0.373541   0.373838
# lvo_drip_ship_ivt_utility_shift      0.040931   0.041228
# lvo_drip_ship_mt_mrs0-2              0.376712   0.377393
# lvo_drip_ship_mt_mrs_shift          -0.196524  -0.198128
# lvo_drip_ship_mt_utility             0.438965   0.439608
# lvo_drip_ship_mt_utility_shift       0.040931   0.041228
# mothership_ivt_time                     174.8      174.8
# mothership_mt_time                      174.8      174.8
# nlvo_mothership_ivt_mrs0-2            0.67573    0.67573
# nlvo_mothership_ivt_mrs_shift       -0.481854  -0.481854
# nlvo_mothership_ivt_utility          0.688423   0.688423
# nlvo_mothership_ivt_utililityshift   0.088783   0.088783
# lvo_mothership_ivt_mrs0-2            0.309438   0.309438
# lvo_mothership_ivt_mrs_shift         -0.19332   -0.19332
# lvo_mothership_ivt_utility           0.372949   0.372949
# lvo_mothership_ivt_utility_shift     0.040339   0.040339
# lvo_mothership_mt_mrs0-2             0.433405   0.433405
# lvo_mothership_mt_mrs_shift          -0.19332   -0.19332
# lvo_mothership_mt_utility            0.491906   0.491906
# lvo_mothership_mt_utility_shift      0.040339   0.040339
# msu_ivt_time                            109.8      109.8
# msu_mt_time                             184.6      184.6
# msu_occupied_treatment                   79.6       79.6
# msu_occupied_no_treatment                59.8       59.8
# nlvo_msu_ivt_mrs0-2                  0.705514   0.705514
# nlvo_msu_ivt_mrs_shift              -0.638272  -0.638272
# nlvo_msu_ivt_utility                 0.715603   0.715603
# nlvo_msu_ivt_utililityshift          0.115963   0.115963
# lvo_msu_ivt_mrs0-2                   0.328146   0.328146
# lvo_msu_ivt_mrs_shift               -0.290098  -0.290098
# lvo_msu_ivt_utility                  0.390717   0.390717
# lvo_msu_ivt_utility_shift            0.058107   0.058107
# lvo_msu_mt_mrs0-2                    0.427075   0.427075
# lvo_msu_mt_mrs_shift                -0.290098  -0.290098
# lvo_msu_mt_utility                   0.486042   0.486042
# lvo_msu_mt_utility_shift             0.058107   0.058107

# %%
continuous_outcome = Continuous_outcome()

# nLVO outcome (stroke type = 1)
outcome_inputs_df = pd.DataFrame()
outcome_inputs_df['stroke_type_code'] = np.repeat(1, len(model.full_results))
outcome_inputs_df['onset_to_needle_mins'] = model.full_results['drip_ship_ivt_time']
outcome_inputs_df['ivt_chosen_bool'] = 1
outcome_inputs_df['onset_to_puncture_mins'] = 999999
outcome_inputs_df['mt_chosen_bool'] = 0

continuous_outcome.assign_patients_to_trial(outcome_inputs_df)
# Calculate outcomes:
patient_data_dict, outcomes_by_stroke_type, full_cohort_outcomes = (
    continuous_outcome.calculate_outcomes())

# %%
outcomes_by_stroke_type
# Out:
# {'lvo_ivt_each_patient_mrs_dist_post_stroke': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'lvo_ivt_mrs_not_treated': 3.6399999993999996,
#  'lvo_ivt_mrs_no_effect': 3.7229999994,
#  'lvo_ivt_each_patient_mrs_post_stroke': array([nan, nan, nan, ..., nan, nan, nan]),
#  'lvo_ivt_each_patient_mrs_shift': array([nan, nan, nan, ..., nan, nan, nan]),
#  'lvo_ivt_utility_not_treated': 0.33261,
#  'lvo_ivt_utility_no_effect': 0.32093,
#  'lvo_ivt_each_patient_utility_post_stroke': array([nan, nan, nan, ..., nan, nan, nan]),
#  'lvo_ivt_each_patient_utility_shift': array([nan, nan, nan, ..., nan, nan, nan]),
#  'lvo_ivt_valid_patients_mean_mrs_shift': nan,
#  'lvo_ivt_valid_patients_mean_utility_shift': nan,
#  'lvo_ivt_treated_patients_mean_mrs_shift': nan,
#  'lvo_ivt_treated_patients_mean_utility_shift': nan,
#  'lvo_mt_each_patient_mrs_dist_post_stroke': array([[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]),
#  'lvo_mt_mrs_not_treated': 3.6399999993999996,
#  'lvo_mt_mrs_no_effect': 3.7329999993999996,
#  'lvo_mt_each_patient_mrs_post_stroke': array([nan, nan, nan, ..., nan, nan, nan]),
#  'lvo_mt_each_patient_mrs_shift': array([nan, nan, nan, ..., nan, nan, nan]),
#  'lvo_mt_utility_not_treated': 0.33261,
#  'lvo_mt_utility_no_effect': 0.31943,
#  'lvo_mt_each_patient_utility_post_stroke': array([nan, nan, nan, ..., nan, nan, nan]),
#  'lvo_mt_each_patient_utility_shift': array([nan, nan, nan, ..., nan, nan, nan]),
#  'lvo_mt_valid_patients_mean_mrs_shift': nan,
#  'lvo_mt_valid_patients_mean_utility_shift': nan,
#  'lvo_mt_treated_patients_mean_mrs_shift': nan,
#  'lvo_mt_treated_patients_mean_utility_shift': nan,
#  'nlvo_ivt_each_patient_mrs_dist_post_stroke': array([[0.3176627 , 0.55846981, 0.67676405, ..., 0.90773127, 0.9468885 ,
#          1.        ],
#         [0.3169122 , 0.55792113, 0.67624749, ..., 0.90747304, 0.94672901,
#          1.        ],
#         [0.3176627 , 0.55846981, 0.67676405, ..., 0.90773127, 0.9468885 ,
#          1.        ],
#         ...,
#         [0.31909812, 0.55951689, 0.67774902, ..., 0.90822245, 0.94719172,
#          1.        ],
#         [0.3176627 , 0.55846981, 0.67676405, ..., 0.90773127, 0.9468885 ,
#          1.        ],
#         [0.3176627 , 0.55846981, 0.67676405, ..., 0.90773127, 0.9468885 ,
#          1.        ]]),
#  'nlvo_ivt_mrs_not_treated': 2.2799999994,
#  'nlvo_ivt_mrs_no_effect': 2.3189999994,
#  'nlvo_ivt_each_patient_mrs_post_stroke': array([1.79276311, 1.79545371, 1.79276311, ..., 1.78763069, 1.79276311,
#         1.79276311]),
#  'nlvo_ivt_each_patient_mrs_shift': array([-0.48723689, -0.48454629, -0.48723689, ..., -0.49236931,
#         -0.48723689, -0.48723689]),
#  'nlvo_ivt_utility_not_treated': 0.59964,
#  'nlvo_ivt_utility_no_effect': 0.59356,
#  'nlvo_ivt_each_patient_utility_post_stroke': array([0.68936916, 0.68889625, 0.68936916, ..., 0.69027072, 0.68936916,
#         0.68936916]),
#  'nlvo_ivt_each_patient_utility_shift': array([0.08972916, 0.08925625, 0.08972916, ..., 0.09063072, 0.08972916,
#         0.08972916]),
#  'nlvo_ivt_valid_patients_mean_mrs_shift': -0.48242732472224426,
#  'nlvo_ivt_valid_patients_mean_utility_shift': 0.08887808209142539,
#  'nlvo_ivt_treated_patients_mean_mrs_shift': -0.48242732472224426,
#  'nlvo_ivt_treated_patients_mean_utility_shift': 0.08887808209142539}

# %%
outcomes_by_stroke_type['nlvo_ivt_each_patient_mrs_dist_post_stroke'][:,2]
# Out:
# array([0.67676405, 0.67624749, 0.67676405, ..., 0.67774902, 0.67676405,
#        0.67676405])

# %%
continuous_outcome.assign_patients_to_trial(outcome_inputs_df.head(3))
# Calculate outcomes:
patient_data_dict, outcomes_by_stroke_type, full_cohort_outcomes = (
    continuous_outcome.calculate_outcomes())
# Out:
# /home/michael/miniconda3/envs/muster/lib/python3.10/site-packages/stroke_outcome/continuous_outcome.py:360: UserWarning: Previous patient data has been deleted because this new data has a different number of patients.
#   warnings.warn(warning_message)
