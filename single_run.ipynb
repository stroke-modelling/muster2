# %% [markdown]
# # MSU Deterministic Model

# %%
from classes.geography_processing import Geoprocessing

geo = Geoprocessing()
geo.run()

# %%
geo.combined_data.head()
# Out:
#           nearest_ivt_unit  nearest_ivt_time nearest_mt_unit  \
# LSOA
# Adur 001A           BN25BE              17.6          BN25BE
# Adur 001B           BN25BE              18.7          BN25BE
# Adur 001C          BN112DH              17.6          BN25BE
# Adur 001D          BN112DH              17.6          BN25BE
# Adur 001E          BN112DH              16.5          BN25BE
#
#            nearest_mt _time transfer_unit  transfer_required  transfer_time  \
# LSOA
# Adur 001A              17.6        BN25BE              False            0.0
# Adur 001B              18.7        BN25BE              False            0.0
# Adur 001C              19.8        BN25BE               True           31.6
# Adur 001D              19.8        BN25BE               True           31.6
# Adur 001E              19.8        BN25BE               True           31.6
#
#           nearest_msu_unit  nearest_msu_time  Admissions  England
# LSOA
# ...
